# %% [markdown]
# # Carga de datos

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

# Ruta del archivo
file_path = '/content/drive/My Drive/ar_properties.csv'

# Cargo el archivo en un DataFrame
ar_properties_df = pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %%
ar_properties_df.head()
# Out:
#                          id    ad_type  start_date    end_date  created_on  \
# 0  S0we3z3V2JpHUJreqQ2t/w==  Propiedad  2019-04-14  2019-06-14  2019-04-14
# 1  kMxcmAS8NvrynGBVbMOEaQ==  Propiedad  2019-04-14  2019-04-16  2019-04-14
# 2  Ce3ojF+ZTOkB8d+LI9dpxg==  Propiedad  2019-04-14  9999-12-31  2019-04-14
# 3  AUGpj3raGmOCiulSMGIBPA==  Propiedad  2019-04-14  9999-12-31  2019-04-14
# 4  m+MwZmJl3OoxmfWcB//sBA==  Propiedad  2019-04-14  2019-07-09  2019-04-14
#
#          lat        lon         l1                        l2              l3  \
# 0 -34.943312 -54.929656    Uruguay                 Maldonado  Punta del Este
# 1 -34.631810 -58.420599  Argentina           Capital Federal           Boedo
# 2        NaN        NaN  Argentina  Bs.As. G.B.A. Zona Norte             NaN
# 3 -34.654705 -58.790894  Argentina  Bs.As. G.B.A. Zona Oeste          Moreno
# 4 -34.654949 -58.787117  Argentina  Bs.As. G.B.A. Zona Oeste          Moreno
#
#    ... bedrooms bathrooms  surface_total  surface_covered    price  currency  \
# 0  ...      NaN       1.0           45.0             40.0  13000.0       UYU
# 1  ...      NaN       NaN            NaN              NaN      0.0       NaN
# 2  ...      NaN       1.0          200.0              NaN      NaN       NaN
# 3  ...      NaN       2.0          460.0            100.0      NaN       NaN
# 4  ...      NaN       3.0          660.0            148.0      NaN       NaN
#
#    price_period                                              title  \
# 0       Mensual                           Departamento - Roosevelt
# 1       Mensual                                         PH - Boedo
# 2           NaN              Ituzaingo  1100 - $ 1 - Casa Alquiler
# 3       Mensual   Dr. Vera   300 - Consulte precio - Casa en Venta
# 4       Mensual  L. N. Alem   2400 - Consulte precio - Casa en ...
#
#    property_type operation_type
# 0   Departamento       Alquiler
# 1             PH          Venta
# 2           Casa       Alquiler
# 3           Casa          Venta
# 4           Casa          Venta
#
# [5 rows x 24 columns]

# %% [markdown]
# # 1- Filtre únicamente las propiedades en Argentina.

# %%
# Creo un nuevo DataFrame solo con las propiedades de Argentina
df_argentina = ar_properties_df[ar_properties_df['l1'] == 'Argentina']

# %%
#df_argentina.head()

# %% [markdown]
# # Análisis exploratorio

# %%
df_argentina.shape
# Out:
# (374977, 24)

# %%
df_argentina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 374977 entries, 1 to 388890
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               374977 non-null  object
#  1   ad_type          374977 non-null  object
#  2   start_date       374977 non-null  object
#  3   end_date         374977 non-null  object
#  4   created_on       374977 non-null  object
#  5   lat              325591 non-null  float64
#  6   lon              325591 non-null  float64
#  7   l1               374977 non-null  object
#  8   l2               374977 non-null  object
#  9   l3               368952 non-null  object
#  10  l4               115268 non-null  object
#  11  l5               2406 non-null    object
#  12  l6               0 non-null       float64
#  13  rooms            235830 non-null  float64
#  14  bedrooms         152764 non-null  float64
#  15  bathrooms        282784 non-null  float64
#  16  surface_total    302852 non-null  float64
#  17  surface_covered  280222 non-null  float64
#  18  price            354448 non-null  float64
#  19  currency         346744 non-null  object
#  20  price_period     214400 non-null  object
#  21  title            374977 non-null  object
#  22  property_type    374977 non-null  object
#  23  operation_type   374977 non-null  object
# dtypes: float64(9), object(15)
# memory usage: 71.5+ MB

# %%
#Convierto las columnas de fechas a objetos de tipo datetime y elimino timezone
def a_fecha(dataframe, columna):
  dataframe.loc[:, columna] = pd.to_datetime(dataframe[columna], errors='coerce')

a_fecha(df_argentina,'start_date')
a_fecha(df_argentina,'end_date')

# %%
#Me quedo con las columnas nùmericas y el tag de salida para aplicar el modelo
columnas_num= ['lat', 'lon', 'l6', 'rooms', 'bedrooms', 'bathrooms', 'surface_total', 'surface_covered', 'price', 'operation_type']
df_modelo = df_argentina[columnas_num]
df_modelo.head()
# Out:
#          lat        lon  l6  rooms  bedrooms  bathrooms  surface_total  \
# 1 -34.631810 -58.420599 NaN    NaN       NaN        NaN            NaN
# 2        NaN        NaN NaN    2.0       NaN        1.0          200.0
# 3 -34.654705 -58.790894 NaN    2.0       NaN        2.0          460.0
# 4 -34.654949 -58.787117 NaN    2.0       NaN        3.0          660.0
# 5 -32.935473 -60.683979 NaN    4.0       NaN        1.0            NaN
#
#    surface_covered  price operation_type
# 1              NaN    0.0          Venta
# 2              NaN    NaN       Alquiler
# 3            100.0    NaN          Venta
# 4            148.0    NaN          Venta
# 5             89.0    NaN          Venta

# %%
df_modelo.isnull().sum()
# Out:
# lat                 49386
# lon                 49386
# l6                 374977
# rooms              139147
# bedrooms           222213
# bathrooms           92193
# surface_total       72125
# surface_covered     94755
# price               20529
# operation_type          0
# dtype: int64

# %%
#Elimino aquellas columnas que tienen mas del 50% de sus valores nulos
thresh = df_modelo.shape[0] * 0.5
df_modelo = df_modelo.dropna(axis=1, thresh=thresh)
df_modelo.head()
# Out:
#          lat        lon  rooms  bathrooms  surface_total  surface_covered  \
# 1 -34.631810 -58.420599    NaN        NaN            NaN              NaN
# 2        NaN        NaN    2.0        1.0          200.0              NaN
# 3 -34.654705 -58.790894    2.0        2.0          460.0            100.0
# 4 -34.654949 -58.787117    2.0        3.0          660.0            148.0
# 5 -32.935473 -60.683979    4.0        1.0            NaN             89.0
#
#    price operation_type
# 1    0.0          Venta
# 2    NaN       Alquiler
# 3    NaN          Venta
# 4    NaN          Venta
# 5    NaN          Venta

# %%
# Imputo valores nulos con la media en las columnas numéricas
for column in df_modelo.select_dtypes(include=['float64']).columns:
    df_modelo[column].fillna(df_modelo[column].mean(), inplace=True)
df_modelo.isnull().sum()
# Out:
# lat                0
# lon                0
# rooms              0
# bathrooms          0
# surface_total      0
# surface_covered    0
# price              0
# operation_type     0
# dtype: int64

# %% [markdown]
# # 2- Utilice algún modelo para clasificar las propiedades en venta y alquiler que tome como variables de entrada las características de la propiedad.

# %%
#Cargo librerias para aplicar regresión lineal
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

#Separo los predictores del tag de salida
X_logistica = df_modelo.drop('operation_type', axis=1)
y_logistica= df_modelo['operation_type']

# %%
#Separo los datos en conjuntos de entrenamiento y prueba
X_train_log, X_test_log, y_train_log, y_test_log = train_test_split(X_logistica, y_logistica, test_size=0.2, random_state=42)

# %%
# Normalizo las características
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_log)
X_test_scaled = scaler.transform(X_test_log)

# %%
#Entreno el modelo
model = LogisticRegression()
model.fit(X_train_scaled, y_train_log)
# Out:
# LogisticRegression()

# %%
# Hacer predicciones en el conjunto de prueba
y_pred_log = model.predict(X_test_scaled)

# %%
# Evaluo el rendimiento del modelo
accuracy = accuracy_score(y_test_log, y_pred_log)
print("Precisión del modelo:", accuracy)
# Out:
# Precisión del modelo: 0.8650061336604619

# %%
# Imprimir el reporte de clasificación
print(classification_report(y_test_log, y_pred_log))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                    precision    recall  f1-score   support
#
#          Alquiler       0.71      0.88      0.79     20334
# Alquiler temporal       0.00      0.00      0.00      2928
#             Venta       0.94      0.91      0.92     51734
#
#          accuracy                           0.87     74996
#         macro avg       0.55      0.60      0.57     74996
#      weighted avg       0.84      0.87      0.85     74996
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Este valor de precisión dice que el modelo es bastante bueno para distinguir entre propiedades en venta y en alquiler. Sin embargo, mientras es muy eficaz prediciendo propiedades en venta, tiene grandes dificultades para clasificar propiedades de alquiler temporal. Esta diferencia de rendimiento parece deberse a la disparidad entre número de instancias para cada una.

# %% [markdown]
# # 3- Ajuste un modelo para describir el precio en función de las características de una propiedad

# %%
#Preparo el dataset para realizar una regresión lineal
#Copio el df con las columnas numericas, la columna de localidades y  el tag anterior a otro dataframe
columnas_lineal= ['l2','lat', 'lon', 'rooms', 'bedrooms', 'bathrooms', 'surface_total', 'surface_covered', 'price', 'operation_type']
df_lineal = df_argentina[columnas_lineal]
df_lineal.head()
# Out:
#                          l2        lat        lon  rooms  bedrooms  bathrooms  \
# 1           Capital Federal -34.631810 -58.420599    NaN       NaN        NaN
# 2  Bs.As. G.B.A. Zona Norte        NaN        NaN    2.0       NaN        1.0
# 3  Bs.As. G.B.A. Zona Oeste -34.654705 -58.790894    2.0       NaN        2.0
# 4  Bs.As. G.B.A. Zona Oeste -34.654949 -58.787117    2.0       NaN        3.0
# 5                  Santa Fe -32.935473 -60.683979    4.0       NaN        1.0
#
#    surface_total  surface_covered  price operation_type
# 1            NaN              NaN    0.0          Venta
# 2          200.0              NaN    NaN       Alquiler
# 3          460.0            100.0    NaN          Venta
# 4          660.0            148.0    NaN          Venta
# 5            NaN             89.0    NaN          Venta

# %%
#Trnasformo las variables categóricas a numericas
df_encoded = pd.get_dummies(df_lineal, columns=['l2','operation_type'])
df_encoded.shape
df_encoded.head()
# Out:
#          lat        lon  rooms  bedrooms  bathrooms  surface_total  \
# 1 -34.631810 -58.420599    NaN       NaN        NaN            NaN
# 2        NaN        NaN    2.0       NaN        1.0          200.0
# 3 -34.654705 -58.790894    2.0       NaN        2.0          460.0
# 4 -34.654949 -58.787117    2.0       NaN        3.0          660.0
# 5 -32.935473 -60.683979    4.0       NaN        1.0            NaN
#
#    surface_covered  price  l2_Bs.As. G.B.A. Zona Norte  \
# 1              NaN    0.0                        False
# 2              NaN    NaN                         True
# 3            100.0    NaN                        False
# 4            148.0    NaN                        False
# 5             89.0    NaN                        False
#
#    l2_Bs.As. G.B.A. Zona Oeste  ...  l2_San Juan  l2_San Luis  l2_Santa Cruz  \
# 1                        False  ...        False        False          False
# 2                        False  ...        False        False          False
# 3                         True  ...        False        False          False
# 4                         True  ...        False        False          False
# 5                        False  ...        False        False          False
#
#    l2_Santa Fe  l2_Santiago Del Estero  l2_Tierra Del Fuego  l2_Tucumán  \
# 1        False                   False                False       False
# 2        False                   False                False       False
# 3        False                   False                False       False
# 4        False                   False                False       False
# 5         True                   False                False       False
#
#    operation_type_Alquiler  operation_type_Alquiler temporal  \
# 1                    False                             False
# 2                     True                             False
# 3                    False                             False
# 4                    False                             False
# 5                    False                             False
#
#    operation_type_Venta
# 1                  True
# 2                 False
# 3                  True
# 4                  True
# 5                  True
#
# [5 rows x 39 columns]

# %%
#Reemplazo los valores nulos en todas las columnas por sus medias
medias = df_encoded.mean()
df_sin_nulos = df_encoded.fillna(medias)

# %%
#Importo librerías
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Separo predictores del tag de salida
X_lineal = df_sin_nulos.drop('price', axis=1)
y_lineal = df_sin_nulos['price']

# %%
#Separo los datos en conjuntos de entrenamiento y prueba
X_train_lin, X_test_lin, y_train_lin, y_test_lin = train_test_split(X_lineal, y_lineal, test_size=0.2, random_state=42)

# %%
# Normalizo las características
scaler = StandardScaler()
X_train_scaled_lin = scaler.fit_transform(X_train_lin)
X_test_scaled_lin = scaler.transform(X_test_lin)

# %%
#Entreno el modelo
model = LinearRegression()
model.fit(X_train_lin, y_train_lin)
# Out:
# LinearRegression()

# %%
# Realizo predicciones en el conjunto de prueba
y_pred_lin = model.predict(X_test_lin)

# %%
# Evaluo el modelo
mse = mean_squared_error(y_test_lin, y_pred_lin)
r2 = r2_score(y_test_lin, y_pred_lin)

print("Error Cuadrático Medio (MSE):", mse)
print("R cuadrado:", r2)
# Out:
# Error Cuadrático Medio (MSE): 6897176265995.297
# R cuadrado: 0.0036527426408550223

# %% [markdown]
# Los valores del error cuadrático medio y el R cuadrado muestran que el modelo no es bueno. Esto podrìa deberse a una baja relaciòn lineal entre las variables

# %%
#Observo la correlaciòn y veo que el precio tiene muy baja colilinealidad con los otros predictores
df_encoded.corr()
# Out:
#                                        lat       lon     rooms  bedrooms  \
# lat                               1.000000 -0.152257  0.057904  0.027013
# lon                              -0.152257  1.000000 -0.108939 -0.023686
# rooms                             0.057904 -0.108939  1.000000  0.841634
# bedrooms                          0.027013 -0.023686  0.841634  1.000000
# bathrooms                         0.006354  0.003570  0.618151  0.668809
# surface_total                     0.009385 -0.067799  0.088419  0.097768
# surface_covered                   0.008657 -0.000743  0.053325  0.046879
# price                             0.020189 -0.011263  0.013738  0.043487
# l2_Bs.As. G.B.A. Zona Norte       0.014381  0.142300  0.081606  0.110781
# l2_Bs.As. G.B.A. Zona Oeste      -0.015345  0.088583  0.000086 -0.007111
# l2_Bs.As. G.B.A. Zona Sur        -0.039741  0.135160  0.055259  0.008259
# l2_Buenos Aires Costa Atlántica  -0.473572  0.240014 -0.044440 -0.036132
# l2_Buenos Aires Interior         -0.144131 -0.038562  0.054346  0.000234
# l2_Capital Federal               -0.027703  0.307018 -0.134601 -0.050490
# l2_Catamarca                      0.047679 -0.041864  0.002210  0.001379
# l2_Chaco                          0.127062  0.006846 -0.006071 -0.001344
# l2_Chubut                        -0.185907 -0.134414  0.007130 -0.001048
# l2_Corrientes                     0.086196  0.009198 -0.012192  0.001620
# l2_Córdoba                        0.378490 -0.488442  0.066869  0.006924
# l2_Entre Ríos                     0.098086  0.007206 -0.002534 -0.003320
# l2_Formosa                        0.024721 -0.000353 -0.004018       NaN
# l2_Jujuy                          0.143724 -0.067383  0.010433  0.003758
# l2_La Pampa                      -0.034037 -0.076928  0.007169 -0.001740
# l2_La Rioja                       0.030758 -0.037368 -0.007267 -0.001514
# l2_Mendoza                        0.058147 -0.319277  0.069532  0.015678
# l2_Misiones                       0.223567  0.097111  0.021002 -0.003965
# l2_Neuquén                       -0.253893 -0.425741  0.018112  0.002803
# l2_Río Negro                     -0.255773 -0.382024  0.023273  0.004129
# l2_Salta                          0.300992 -0.153841  0.023191  0.014524
# l2_San Juan                       0.050262 -0.125568  0.033121  0.005596
# l2_San Luis                       0.039756 -0.116378  0.002672  0.001790
# l2_Santa Cruz                    -0.124249 -0.073641  0.002741 -0.000103
# l2_Santa Fe                       0.244343 -0.141154 -0.007883 -0.042911
# l2_Santiago Del Estero            0.042800 -0.024044 -0.004734 -0.001630
# l2_Tierra Del Fuego              -0.264475 -0.094635  0.003393 -0.000687
# l2_Tucumán                        0.301324 -0.188911  0.017483  0.000313
# operation_type_Alquiler           0.007997  0.004075 -0.106051 -0.049579
# operation_type_Alquiler temporal -0.014482  0.049049 -0.104877 -0.026539
# operation_type_Venta             -0.001406 -0.025116  0.151250  0.057789
#
#                                   bathrooms  surface_total  surface_covered  \
# lat                                0.006354       0.009385         0.008657
# lon                                0.003570      -0.067799        -0.000743
# rooms                              0.618151       0.088419         0.053325
# bedrooms                           0.668809       0.097768         0.046879
# bathrooms                          1.000000       0.081148         0.061721
# surface_total                      0.081148       1.000000         0.269234
# surface_covered                    0.061721       0.269234         1.000000
# price                              0.026677       0.008166         0.006969
# l2_Bs.As. G.B.A. Zona Norte        0.248115       0.009860         0.000858
# l2_Bs.As. G.B.A. Zona Oeste       -0.044524       0.000971        -0.000606
# l2_Bs.As. G.B.A. Zona Sur         -0.027626       0.009782         0.006212
# l2_Buenos Aires Costa Atlántica   -0.020099      -0.013453        -0.002663
# l2_Buenos Aires Interior          -0.002414       0.069156         0.002732
# l2_Capital Federal                -0.103921      -0.060201        -0.005352
# l2_Catamarca                      -0.003518       0.001260        -0.000032
# l2_Chaco                          -0.013060      -0.001808        -0.000379
# l2_Chubut                         -0.008174       0.003050        -0.000315
# l2_Corrientes                     -0.004240       0.000875        -0.000088
# l2_Córdoba                        -0.006503       0.025302         0.003026
# l2_Entre Ríos                     -0.014307       0.003913        -0.000576
# l2_Formosa                              NaN       0.000289         0.017855
# l2_Jujuy                           0.001525       0.008390         0.000535
# l2_La Pampa                        0.007531       0.003800         0.001434
# l2_La Rioja                       -0.005663      -0.000625        -0.000016
# l2_Mendoza                         0.011834       0.039596         0.000004
# l2_Misiones                       -0.010478       0.016901         0.019300
# l2_Neuquén                        -0.001210       0.023636         0.000010
# l2_Río Negro                       0.001341       0.035551        -0.000444
# l2_Salta                           0.005878       0.006273         0.000150
# l2_San Juan                        0.001576       0.018226         0.000200
# l2_San Luis                       -0.004290       0.020134        -0.000038
# l2_Santa Cruz                      0.003471       0.003706         0.000749
# l2_Santa Fe                       -0.085449      -0.005880        -0.002464
# l2_Santiago Del Estero            -0.002209       0.005820         0.000017
# l2_Tierra Del Fuego               -0.009749      -0.001388        -0.000190
# l2_Tucumán                         0.008217      -0.002482        -0.000346
# operation_type_Alquiler           -0.060126      -0.030504        -0.001987
# operation_type_Alquiler temporal  -0.068097      -0.016111        -0.002587
# operation_type_Venta               0.088890       0.035858         0.002993
#
#                                      price  l2_Bs.As. G.B.A. Zona Norte  \
# lat                               0.020189                     0.014381
# lon                              -0.011263                     0.142300
# rooms                             0.013738                     0.081606
# bedrooms                          0.043487                     0.110781
# bathrooms                         0.026677                     0.248115
# surface_total                     0.008166                     0.009860
# surface_covered                   0.006969                     0.000858
# price                             1.000000                     0.001649
# l2_Bs.As. G.B.A. Zona Norte       0.001649                     1.000000
# l2_Bs.As. G.B.A. Zona Oeste      -0.006553                    -0.140120
# l2_Bs.As. G.B.A. Zona Sur        -0.007082                    -0.138800
# l2_Buenos Aires Costa Atlántica  -0.009646                    -0.145550
# l2_Buenos Aires Interior         -0.001876                    -0.074984
# l2_Capital Federal               -0.004694                    -0.343588
# l2_Catamarca                      0.000510                    -0.008470
# l2_Chaco                          0.013077                    -0.018004
# l2_Chubut                         0.000048                    -0.019432
# l2_Corrientes                     0.029279                    -0.012398
# l2_Córdoba                       -0.001521                    -0.124144
# l2_Entre Ríos                     0.007392                    -0.037794
# l2_Formosa                       -0.000059                    -0.002760
# l2_Jujuy                          0.006011                    -0.013942
# l2_La Pampa                       0.001096                    -0.024548
# l2_La Rioja                       0.000192                    -0.006172
# l2_Mendoza                        0.005779                    -0.044520
# l2_Misiones                       0.009240                    -0.033626
# l2_Neuquén                        0.000508                    -0.054512
# l2_Río Negro                     -0.000101                    -0.045899
# l2_Salta                          0.005484                    -0.030928
# l2_San Juan                       0.006633                    -0.018509
# l2_San Luis                      -0.000056                    -0.023240
# l2_Santa Cruz                    -0.000129                    -0.009628
# l2_Santa Fe                       0.013779                    -0.159471
# l2_Santiago Del Estero            0.009307                    -0.006374
# l2_Tierra Del Fuego               0.000225                    -0.013805
# l2_Tucumán                        0.012345                    -0.039114
# operation_type_Alquiler          -0.031043                     0.025001
# operation_type_Alquiler temporal -0.010341                    -0.055502
# operation_type_Venta              0.034171                    -0.000583
#
#                                   l2_Bs.As. G.B.A. Zona Oeste  ...  \
# lat                                                 -0.015345  ...
# lon                                                  0.088583  ...
# rooms                                                0.000086  ...
# bedrooms                                            -0.007111  ...
# bathrooms                                           -0.044524  ...
# surface_total                                        0.000971  ...
# surface_covered                                     -0.000606  ...
# price                                               -0.006553  ...
# l2_Bs.As. G.B.A. Zona Norte                         -0.140120  ...
# l2_Bs.As. G.B.A. Zona Oeste                          1.000000  ...
# l2_Bs.As. G.B.A. Zona Sur                           -0.081716  ...
# l2_Buenos Aires Costa Atlántica                     -0.085691  ...
# l2_Buenos Aires Interior                            -0.044146  ...
# l2_Capital Federal                                  -0.202283  ...
# l2_Catamarca                                        -0.004987  ...
# l2_Chaco                                            -0.010600  ...
# l2_Chubut                                           -0.011441  ...
# l2_Corrientes                                       -0.007299  ...
# l2_Córdoba                                          -0.073088  ...
# l2_Entre Ríos                                       -0.022251  ...
# l2_Formosa                                          -0.001625  ...
# l2_Jujuy                                            -0.008208  ...
# l2_La Pampa                                         -0.014452  ...
# l2_La Rioja                                         -0.003633  ...
# l2_Mendoza                                          -0.026211  ...
# l2_Misiones                                         -0.019797  ...
# l2_Neuquén                                          -0.032093  ...
# l2_Río Negro                                        -0.027022  ...
# l2_Salta                                            -0.018208  ...
# l2_San Juan                                         -0.010897  ...
# l2_San Luis                                         -0.013682  ...
# l2_Santa Cruz                                       -0.005669  ...
# l2_Santa Fe                                         -0.093886  ...
# l2_Santiago Del Estero                              -0.003753  ...
# l2_Tierra Del Fuego                                 -0.008127  ...
# l2_Tucumán                                          -0.023028  ...
# operation_type_Alquiler                              0.031883  ...
# operation_type_Alquiler temporal                    -0.054830  ...
# operation_type_Venta                                -0.007471  ...
#
#                                   l2_San Juan  l2_San Luis  l2_Santa Cruz  \
# lat                                  0.050262     0.039756      -0.124249
# lon                                 -0.125568    -0.116378      -0.073641
# rooms                                0.033121     0.002672       0.002741
# bedrooms                             0.005596     0.001790      -0.000103
# bathrooms                            0.001576    -0.004290       0.003471
# surface_total                        0.018226     0.020134       0.003706
# surface_covered                      0.000200    -0.000038       0.000749
# price                                0.006633    -0.000056      -0.000129
# l2_Bs.As. G.B.A. Zona Norte         -0.018509    -0.023240      -0.009628
# l2_Bs.As. G.B.A. Zona Oeste         -0.010897    -0.013682      -0.005669
# l2_Bs.As. G.B.A. Zona Sur           -0.010795    -0.013553      -0.005615
# l2_Buenos Aires Costa Atlántica     -0.011319    -0.014212      -0.005888
# l2_Buenos Aires Interior            -0.005832    -0.007322      -0.003033
# l2_Capital Federal                  -0.026721    -0.033550      -0.013900
# l2_Catamarca                        -0.000659    -0.000827      -0.000343
# l2_Chaco                            -0.001400    -0.001758      -0.000728
# l2_Chubut                           -0.001511    -0.001897      -0.000786
# l2_Corrientes                       -0.000964    -0.001211      -0.000502
# l2_Córdoba                          -0.009655    -0.012122      -0.005022
# l2_Entre Ríos                       -0.002939    -0.003690      -0.001529
# l2_Formosa                          -0.000215    -0.000269      -0.000112
# l2_Jujuy                            -0.001084    -0.001361      -0.000564
# l2_La Pampa                         -0.001909    -0.002397      -0.000993
# l2_La Rioja                         -0.000480    -0.000603      -0.000250
# l2_Mendoza                          -0.003462    -0.004347      -0.001801
# l2_Misiones                         -0.002615    -0.003283      -0.001360
# l2_Neuquén                          -0.004239    -0.005323      -0.002205
# l2_Río Negro                        -0.003570    -0.004482      -0.001857
# l2_Salta                            -0.002405    -0.003020      -0.001251
# l2_San Juan                          1.000000    -0.001807      -0.000749
# l2_San Luis                         -0.001807     1.000000      -0.000940
# l2_Santa Cruz                       -0.000749    -0.000940       1.000000
# l2_Santa Fe                         -0.012402    -0.015572      -0.006451
# l2_Santiago Del Estero              -0.000496    -0.000622      -0.000258
# l2_Tierra Del Fuego                 -0.001074    -0.001348      -0.000558
# l2_Tucumán                          -0.003042    -0.003819      -0.001582
# operation_type_Alquiler              0.008222     0.003641       0.013714
# operation_type_Alquiler temporal    -0.005516    -0.000136      -0.001220
# operation_type_Venta                -0.005564    -0.003437      -0.012648
#
#                                   l2_Santa Fe  l2_Santiago Del Estero  \
# lat                                  0.244343                0.042800
# lon                                 -0.141154               -0.024044
# rooms                               -0.007883               -0.004734
# bedrooms                            -0.042911               -0.001630
# bathrooms                           -0.085449               -0.002209
# surface_total                       -0.005880                0.005820
# surface_covered                     -0.002464                0.000017
# price                                0.013779                0.009307
# l2_Bs.As. G.B.A. Zona Norte         -0.159471               -0.006374
# l2_Bs.As. G.B.A. Zona Oeste         -0.093886               -0.003753
# l2_Bs.As. G.B.A. Zona Sur           -0.093001               -0.003717
# l2_Buenos Aires Costa Atlántica     -0.097524               -0.003898
# l2_Buenos Aires Interior            -0.050242               -0.002008
# l2_Capital Federal                  -0.230218               -0.009202
# l2_Catamarca                        -0.005675               -0.000227
# l2_Chaco                            -0.012063               -0.000482
# l2_Chubut                           -0.013020               -0.000520
# l2_Corrientes                       -0.008307               -0.000332
# l2_Córdoba                          -0.083182               -0.003325
# l2_Entre Ríos                       -0.025323               -0.001012
# l2_Formosa                          -0.001849               -0.000074
# l2_Jujuy                            -0.009342               -0.000373
# l2_La Pampa                         -0.016448               -0.000657
# l2_La Rioja                         -0.004135               -0.000165
# l2_Mendoza                          -0.029830               -0.001192
# l2_Misiones                         -0.022531               -0.000901
# l2_Neuquén                          -0.036525               -0.001460
# l2_Río Negro                        -0.030754               -0.001229
# l2_Salta                            -0.020723               -0.000828
# l2_San Juan                         -0.012402               -0.000496
# l2_San Luis                         -0.015572               -0.000622
# l2_Santa Cruz                       -0.006451               -0.000258
# l2_Santa Fe                          1.000000               -0.004271
# l2_Santiago Del Estero              -0.004271                1.000000
# l2_Tierra Del Fuego                 -0.009250               -0.000370
# l2_Tucumán                          -0.026208               -0.001048
# operation_type_Alquiler             -0.063351               -0.007438
# operation_type_Alquiler temporal    -0.062417                0.009942
# operation_type_Venta                 0.087135                0.002945
#
#                                   l2_Tierra Del Fuego  l2_Tucumán  \
# lat                                         -0.264475    0.301324
# lon                                         -0.094635   -0.188911
# rooms                                        0.003393    0.017483
# bedrooms                                    -0.000687    0.000313
# bathrooms                                   -0.009749    0.008217
# surface_total                               -0.001388   -0.002482
# surface_covered                             -0.000190   -0.000346
# price                                        0.000225    0.012345
# l2_Bs.As. G.B.A. Zona Norte                 -0.013805   -0.039114
# l2_Bs.As. G.B.A. Zona Oeste                 -0.008127   -0.023028
# l2_Bs.As. G.B.A. Zona Sur                   -0.008051   -0.022811
# l2_Buenos Aires Costa Atlántica             -0.008442   -0.023920
# l2_Buenos Aires Interior                    -0.004349   -0.012323
# l2_Capital Federal                          -0.019929   -0.056466
# l2_Catamarca                                -0.000491   -0.001392
# l2_Chaco                                    -0.001044   -0.002959
# l2_Chubut                                   -0.001127   -0.003194
# l2_Corrientes                               -0.000719   -0.002037
# l2_Córdoba                                  -0.007201   -0.020402
# l2_Entre Ríos                               -0.002192   -0.006211
# l2_Formosa                                  -0.000160   -0.000454
# l2_Jujuy                                    -0.000809   -0.002291
# l2_La Pampa                                 -0.001424   -0.004034
# l2_La Rioja                                 -0.000358   -0.001014
# l2_Mendoza                                  -0.002582   -0.007317
# l2_Misiones                                 -0.001950   -0.005526
# l2_Neuquén                                  -0.003162   -0.008959
# l2_Río Negro                                -0.002662   -0.007543
# l2_Salta                                    -0.001794   -0.005083
# l2_San Juan                                 -0.001074   -0.003042
# l2_San Luis                                 -0.001348   -0.003819
# l2_Santa Cruz                               -0.000558   -0.001582
# l2_Santa Fe                                 -0.009250   -0.026208
# l2_Santiago Del Estero                      -0.000370   -0.001048
# l2_Tierra Del Fuego                          1.000000   -0.002269
# l2_Tucumán                                  -0.002269    1.000000
# operation_type_Alquiler                      0.030185    0.020708
# operation_type_Alquiler temporal            -0.004763   -0.004545
# operation_type_Venta                        -0.026963   -0.017958
#
#                                   operation_type_Alquiler  \
# lat                                              0.007997
# lon                                              0.004075
# rooms                                           -0.106051
# bedrooms                                        -0.049579
# bathrooms                                       -0.060126
# surface_total                                   -0.030504
# surface_covered                                 -0.001987
# price                                           -0.031043
# l2_Bs.As. G.B.A. Zona Norte                      0.025001
# l2_Bs.As. G.B.A. Zona Oeste                      0.031883
# l2_Bs.As. G.B.A. Zona Sur                        0.007969
# l2_Buenos Aires Costa Atlántica                 -0.008607
# l2_Buenos Aires Interior                        -0.006563
# l2_Capital Federal                              -0.013220
# l2_Catamarca                                     0.004078
# l2_Chaco                                         0.028189
# l2_Chubut                                        0.012418
# l2_Corrientes                                    0.012148
# l2_Córdoba                                       0.014121
# l2_Entre Ríos                                    0.009478
# l2_Formosa                                      -0.003420
# l2_Jujuy                                         0.000229
# l2_La Pampa                                      0.013620
# l2_La Rioja                                      0.013304
# l2_Mendoza                                      -0.016375
# l2_Misiones                                      0.023126
# l2_Neuquén                                      -0.008886
# l2_Río Negro                                    -0.019422
# l2_Salta                                         0.008509
# l2_San Juan                                      0.008222
# l2_San Luis                                      0.003641
# l2_Santa Cruz                                    0.013714
# l2_Santa Fe                                     -0.063351
# l2_Santiago Del Estero                          -0.007438
# l2_Tierra Del Fuego                              0.030185
# l2_Tucumán                                       0.020708
# operation_type_Alquiler                          1.000000
# operation_type_Alquiler temporal                -0.122485
# operation_type_Venta                            -0.908134
#
#                                   operation_type_Alquiler temporal  \
# lat                                                      -0.014482
# lon                                                       0.049049
# rooms                                                    -0.104877
# bedrooms                                                 -0.026539
# bathrooms                                                -0.068097
# surface_total                                            -0.016111
# surface_covered                                          -0.002587
# price                                                    -0.010341
# l2_Bs.As. G.B.A. Zona Norte                              -0.055502
# l2_Bs.As. G.B.A. Zona Oeste                              -0.054830
# l2_Bs.As. G.B.A. Zona Sur                                -0.053525
# l2_Buenos Aires Costa Atlántica                          -0.008919
# l2_Buenos Aires Interior                                 -0.023380
# l2_Capital Federal                                        0.183583
# l2_Catamarca                                              0.002799
# l2_Chaco                                                 -0.007476
# l2_Chubut                                                -0.005657
# l2_Corrientes                                            -0.002990
# l2_Córdoba                                               -0.024430
# l2_Entre Ríos                                            -0.005551
# l2_Formosa                                               -0.001146
# l2_Jujuy                                                 -0.001470
# l2_La Pampa                                              -0.007736
# l2_La Rioja                                              -0.000396
# l2_Mendoza                                               -0.009402
# l2_Misiones                                              -0.011367
# l2_Neuquén                                               -0.015807
# l2_Río Negro                                              0.001366
# l2_Salta                                                 -0.006983
# l2_San Juan                                              -0.005516
# l2_San Luis                                              -0.000136
# l2_Santa Cruz                                            -0.001220
# l2_Santa Fe                                              -0.062417
# l2_Santiago Del Estero                                    0.009942
# l2_Tierra Del Fuego                                      -0.004763
# l2_Tucumán                                               -0.004545
# operation_type_Alquiler                                  -0.122485
# operation_type_Alquiler temporal                          1.000000
# operation_type_Venta                                     -0.304294
#
#                                   operation_type_Venta
# lat                                          -0.001406
# lon                                          -0.025116
# rooms                                         0.151250
# bedrooms                                      0.057789
# bathrooms                                     0.088890
# surface_total                                 0.035858
# surface_covered                               0.002993
# price                                         0.034171
# l2_Bs.As. G.B.A. Zona Norte                  -0.000583
# l2_Bs.As. G.B.A. Zona Oeste                  -0.007471
# l2_Bs.As. G.B.A. Zona Sur                     0.014931
# l2_Buenos Aires Costa Atlántica               0.012023
# l2_Buenos Aires Interior                      0.016162
# l2_Capital Federal                           -0.064757
# l2_Catamarca                                 -0.005095
# l2_Chaco                                     -0.023902
# l2_Chubut                                    -0.009532
# l2_Corrientes                                -0.010398
# l2_Córdoba                                   -0.003247
# l2_Entre Ríos                                -0.006755
# l2_Formosa                                    0.003766
# l2_Jujuy                                      0.000400
# l2_La Pampa                                  -0.009809
# l2_La Rioja                                  -0.012603
# l2_Mendoza                                    0.019683
# l2_Misiones                                  -0.017401
# l2_Neuquén                                    0.015197
# l2_Río Negro                                  0.018065
# l2_Salta                                     -0.005221
# l2_San Juan                                  -0.005564
# l2_San Luis                                  -0.003437
# l2_Santa Cruz                                -0.012648
# l2_Santa Fe                                   0.087135
# l2_Santiago Del Estero                        0.002945
# l2_Tierra Del Fuego                          -0.026963
# l2_Tucumán                                   -0.017958
# operation_type_Alquiler                      -0.908134
# operation_type_Alquiler temporal             -0.304294
# operation_type_Venta                          1.000000
#
# [39 rows x 39 columns]
